# %%
import cv2
import numpy as np
from PIL import Image

# %%
# !ls ..
# Out:
# bin   dev  home       lib    media  opt   requirements.txt  run   srv  tmp  var
# boot  etc  ip-camera  lib64  mnt    proc  root		    sbin  sys  usr

# %%
stream_url = "http://166.145.68.221/mjpg/video.mjpg"

control_url = "http://166.145.68.221/view/view.shtml"

# %%
cap = cv2.VideoCapture(stream_url)

while True:
    
    ret, frame = cap.read()
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    print(cap.get(cv2.CAP_PROP_POS_FRAMES))
    print(cap.get(cv2.CAP_PROP_POS_MSEC))
    
    if cv2.waitKey(1) == 27:
        exit(0)
        
    break
# Out:
# 1.0
# -3.68934881474191e+20
# errorTraceback (most recent call last)
# <ipython-input-3-77d33ae894b0> in <module>
#       8     print(cap.get(cv2.CAP_PROP_POS_MSEC))
#       9
# ---> 10     if cv2.waitKey(1) == 27:
#      11         exit(0)
#      12
#
# error: OpenCV(4.5.0) /opencv-4.5.0/modules/highgui/src/window.cpp:717: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvWaitKey'

# %%
Image.fromarray(frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x450 at 0x7EFF69545850>

# %%
# !wget https://chromedriver.storage.googleapis.com/87.0.4280.88/chromedriver_linux64.zip

# %%
from selenium import webdriver
import time

options = webdriver.ChromeOptions()
options.add_argument('headless')
options.add_argument("--no-sandbox")
options.add_argument('window-size=1920x1080')
options.add_argument("disable-gpu")

# Start Chrome Driver
chromedriver = 'utils/chromedriver'

driver = webdriver.Chrome(chromedriver, options=options)

# Open the URL you want to execute JS
URL = 'http://166.145.68.221/view/view.shtml'
driver.get(URL)

# %%
# Execute JS

driver.execute_script("continousMove('zoom', 200)")
time.sleep(1)
driver.execute_script("continousMove('zoom', 0)")

# %%
driver.quit()

# %% [raw]
# continousMove('tilt', '0,100')
# continousMove('tilt', '0,0')
#
# continousMove('pan', '-100,0')
# continousMove('pan', '0,0')
#
# continousMove('zoom', '100')
# continousMove('zoom', '0')
#
# continousMove('focus', '100')
# continousMove('focus', '0')
